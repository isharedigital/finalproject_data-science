# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
df = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/raw/sub_recipe_ingr_assignments.csv')

# %%
df.head()
# Out:
#    SubRecipeId  IngredientId  Quantity
# 0            1             1         1
# 1            1           135         2
# 2            1           138         1
# 3            1           146         1
# 4            1           157         1

# %%
df.shape
# Out:
# (379, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SubRecipeId   379 non-null    int64
#  1   IngredientId  379 non-null    int64
#  2   Quantity      379 non-null    int64
# dtypes: int64(3)
# memory usage: 9.0 KB

# %%
df.isna().sum()
# Out:
# SubRecipeId     0
# IngredientId    0
# Quantity        0
# dtype: int64

# %%
current_date = datetime.now().strftime('%Y%m%d')   
df.to_csv(f'/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/sub_recipe_ingr_assignments_{current_date}.csv', index=False)
