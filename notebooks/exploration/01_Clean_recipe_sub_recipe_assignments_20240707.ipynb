# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
df = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/raw/recipe_sub_recipe_assignments.csv')

# %%
df.head()
# Out:
#    RecipeId  SubRecipeId  Factor
# 0         2            3       1
# 1         2            9       1
# 2         2           10       1
# 3         2           12       1
# 4         6            1       1

# %%
df.shape
# Out:
# (13890, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13890 entries, 0 to 13889
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RecipeId     13890 non-null  int64
#  1   SubRecipeId  13890 non-null  int64
#  2   Factor       13890 non-null  int64
# dtypes: int64(3)
# memory usage: 325.7 KB

# %%
df.isna().sum()
# Out:
# RecipeId       0
# SubRecipeId    0
# Factor         0
# dtype: int64

# %%
current_date = datetime.now().strftime('%Y%m%d')   
df.to_csv(f'/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/recipe_sub_recipe_assignments_{current_date}.csv', index=False)
