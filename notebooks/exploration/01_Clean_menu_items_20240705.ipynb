# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/raw/menu_items.csv')

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
df.head()
# Out:
#                    MenuItemName                         MenuItemDescription  \
# 0  FtL/Ham                       Ham FtLong
# 1  Six/Ham                       Ham 6 inch
# 2  FfB/Ham                       Ham FtFbd
# 3  fBd/Ham                       Ham FlatBd
# 4  Sld/Ham                       Ham Salad
#
#          PLU  MenuItemId  RecipeId
# 0  111000004           1         6
# 1  121000004           2         7
# 2  112000004           3         2
# 3  122000004           4         8
# 4  131000004           5         9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8005 entries, 0 to 8004
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MenuItemName         8005 non-null   object
#  1   MenuItemDescription  8005 non-null   object
#  2   PLU                  8005 non-null   int64
#  3   MenuItemId           8005 non-null   int64
#  4   RecipeId             8005 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 312.8+ KB

# %%
df.isna().sum()
# Out:
# MenuItemName           0
# MenuItemDescription    0
# PLU                    0
# MenuItemId             0
# RecipeId               0
# dtype: int64

# %%
current_date = datetime.now().strftime('%Y%m%d')
df.to_csv(f'/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/menu_items_{current_date}.csv', index=False)
