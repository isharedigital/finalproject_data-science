# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import sys
import os
sys.path.append('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/scripts/')
import data_cleaning

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
df = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/raw/menuitem.csv')

# %%
df.head()
# Out:
#                     MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0  001E0224E4EDA63D6FED96D59E0C1E76  072D3B76BE58E4553A373AF3206D2CA5
# 1  003E4E20196B2F5BDD33CE06D2943EF4  14811D4F3458058007B0B6908C2DA393
# 2  012A55E5551C95A559A7B074AE85117E  22FA6C39B7A15ABB6EB568E66A6B30E1
# 3  01B07F1C6DC6945796571FC78735DA16  915B69612845BBD974C39AC105F5CA8C
# 4  02DE19974DE5304BF243A1C2EC639495  CD6386C802450EDCF13A3D112D1F86EC
#
#   CategoryDescription         DepartmentDescription  \
# 0    Footlong          Footlong Sub
# 1    Fountain          Fountain Drink 21 oz.
# 2    6 Inch            6 Inch Sub
# 3    6 Inch            6 Inch Sub
# 4    Add On            Add On 6in Portion
#
#                                   Description  StoreNumber  \
# 0  Chickn Strips FtLong                              46673
# 1  21oz Fountain Drink                               46673
# 2  B.M.T. 6 inch                                     12631
# ...

# %%
df['StoreNumber'].unique()
# Out:
# array([46673, 12631, 20974,  4904])

# %%
df['DepartmentDescription'].value_counts()
# Out:
# DepartmentDescription
# Footlong Sub                    22812
# 6 Inch Sub                      17555
# Chips                           14154
# Fountain Drink 21 oz.           10155
# Bottled Drink                    8752
# Cookies                          6178
# Add On FT Portion                2251
# Add On 6in Portion               1382
# Single Portion                   1244
# Fountain Drink 30 oz.            1094
# Salad                            1048
# Footlong Flatbread                647
# Soup                              599
# Fountain Drink 40 oz.             590
# 6 inch Portion                    558
# FT Portion                        453
# 6 inch Flatbread                  384
# Side Items                        279
# 6 inch Breakfast                  245
# Mini Sub                          218
# Personal Pizza                    167
# Hot Beverage 12 oz.               157
# 6 inch Breakfast Flatbread        154
# Footlong Breakfast                147
# ...

# %%
# df_1 = df[df['StoreNumber'] == 46673]
# df_2 = df[df['StoreNumber'] == 12631]

# df_1['TaxAmount']/df_1['AdjustedPrice']*100
# df_2['TaxAmount']/df_2['AdjustedPrice']*100

# df_3 = df[df['StoreNumber'] == 20974]
# df_3['TaxAmount']/df_3['AdjustedPrice']*100

df_4 = df[df['StoreNumber'] == 4904]
df_4['TaxAmount']/df_4['AdjustedPrice']*100
# Out:
# 3009          NaN
# 3136     8.500000
# 3138     8.496599
# 3141     8.499225
# 3142     8.500000
#            ...
# 91420    8.498969
# 91425    8.493333
# 91426    0.000000
# 91427    0.000000
# 91428    8.499055
# Length: 29762, dtype: float64

# %%
df.shape
# Out:
# (91431, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91431 entries, 0 to 91430
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MD5KEY_MENUITEM        91431 non-null  object
#  1   MD5KEY_ORDERSALE       91431 non-null  object
#  2   CategoryDescription    91431 non-null  object
#  3   DepartmentDescription  91431 non-null  object
#  4   Description            91431 non-null  object
#  5   StoreNumber            91431 non-null  int64
#  6   TaxInclusiveAmount     91431 non-null  int64
#  7   TaxAmount              91431 non-null  float64
#  8   AdjustedPrice          91431 non-null  float64
#  9   DiscountAmount         91431 non-null  float64
#  10  Price                  91431 non-null  float64
#  11  Quantity               91431 non-null  int64
#  12  PLU                    91431 non-null  int64
#  13  Id                     91431 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# MD5KEY_MENUITEM          0
# MD5KEY_ORDERSALE         0
# CategoryDescription      0
# DepartmentDescription    0
# Description              0
# StoreNumber              0
# TaxInclusiveAmount       0
# TaxAmount                0
# AdjustedPrice            0
# DiscountAmount           0
# Price                    0
# Quantity                 0
# PLU                      0
# Id                       0
# date                     0
# dtype: int64

# %%
# Convert the date column to the datetime data type
df['date'] = pd.to_datetime(df['date'], format='%y-%m-%d')

# %%
df.head()
# Out:
#                     MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0  001E0224E4EDA63D6FED96D59E0C1E76  072D3B76BE58E4553A373AF3206D2CA5
# 1  003E4E20196B2F5BDD33CE06D2943EF4  14811D4F3458058007B0B6908C2DA393
# 2  012A55E5551C95A559A7B074AE85117E  22FA6C39B7A15ABB6EB568E66A6B30E1
# 3  01B07F1C6DC6945796571FC78735DA16  915B69612845BBD974C39AC105F5CA8C
# 4  02DE19974DE5304BF243A1C2EC639495  CD6386C802450EDCF13A3D112D1F86EC
#
#   CategoryDescription         DepartmentDescription  \
# 0    Footlong          Footlong Sub
# 1    Fountain          Fountain Drink 21 oz.
# 2    6 Inch            6 Inch Sub
# 3    6 Inch            6 Inch Sub
# 4    Add On            Add On 6in Portion
#
#                                   Description  StoreNumber  \
# 0  Chickn Strips FtLong                              46673
# 1  21oz Fountain Drink                               46673
# 2  B.M.T. 6 inch                                     12631
# ...

# %%
df['SalesAmount'] = df['AdjustedPrice'] * df['Quantity']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91431 entries, 0 to 91430
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MD5KEY_MENUITEM        91431 non-null  object
#  1   MD5KEY_ORDERSALE       91431 non-null  object
#  2   CategoryDescription    91431 non-null  object
#  3   DepartmentDescription  91431 non-null  object
#  4   Description            91431 non-null  object
#  5   StoreNumber            91431 non-null  int64
#  6   TaxInclusiveAmount     91431 non-null  int64
#  7   TaxAmount              91431 non-null  float64
#  8   AdjustedPrice          91431 non-null  float64
#  9   DiscountAmount         91431 non-null  float64
#  10  Price                  91431 non-null  float64
#  11  Quantity               91431 non-null  int64
#  12  PLU                    91431 non-null  int64
#  13  Id                     91431 non-null  int64
# ...

# %%
df.head()
# Out:
#                     MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0  001E0224E4EDA63D6FED96D59E0C1E76  072D3B76BE58E4553A373AF3206D2CA5
# 1  003E4E20196B2F5BDD33CE06D2943EF4  14811D4F3458058007B0B6908C2DA393
# 2  012A55E5551C95A559A7B074AE85117E  22FA6C39B7A15ABB6EB568E66A6B30E1
# 3  01B07F1C6DC6945796571FC78735DA16  915B69612845BBD974C39AC105F5CA8C
# 4  02DE19974DE5304BF243A1C2EC639495  CD6386C802450EDCF13A3D112D1F86EC
#
#   CategoryDescription         DepartmentDescription  \
# 0    Footlong          Footlong Sub
# 1    Fountain          Fountain Drink 21 oz.
# 2    6 Inch            6 Inch Sub
# 3    6 Inch            6 Inch Sub
# 4    Add On            Add On 6in Portion
#
#                                   Description  StoreNumber  \
# 0  Chickn Strips FtLong                              46673
# 1  21oz Fountain Drink                               46673
# 2  B.M.T. 6 inch                                     12631
# ...

# %%
df.groupby('CategoryDescription').agg(total=('SalesAmount', 'sum')).reset_index().sort_values(by='total', ascending=False)
# Out:
#    CategoryDescription      total
# 7     Footlong          233007.44
# 0     6 Inch             84596.16
# 5     Chips              26503.85
# 2     Bottled Beverage   20494.85
# 8     Fountain           20342.40
# 6     Cookies            12806.82
# 1     Add On              9290.17
# 13    Salad               7492.25
# 14    Soups               1895.84
# 4     Catering            1859.00
# 3     Cash Card           1629.00
# 10    Other Carrier       1098.08
# 12    Pizza                824.64
# 11    Other Misc           469.96
# 9     Hot Beverage         315.84

# %%
plt.figure(figsize=(10, 5))

sns.barplot(data=df.groupby('CategoryDescription').agg(total=('SalesAmount', 'sum')).reset_index().sort_values(by='total', ascending=False),
            x='CategoryDescription',
            y='total')

plt.xticks(rotation=45, ha='center')
plt.show()

# %%
df['CategoryDescription'].unique()
# Out:
# array(['Footlong        ', 'Fountain        ', '6 Inch          ',
#        'Add On          ', 'Bottled Beverage', 'Chips           ',
#        'Cookies         ', 'Pizza           ', 'Soups           ',
#        'Salad           ', 'Other Carrier   ', 'Hot Beverage    ',
#        'Other Misc      ', 'Cash Card       ', 'Catering        '],
#       dtype=object)

# %%
df['CategoryDescription'] = df['CategoryDescription'].str.strip()

# %%
df['CategoryDescription'].unique()
# Out:
# array(['Footlong', 'Fountain', '6 Inch', 'Add On', 'Bottled Beverage',
#        'Chips', 'Cookies', 'Pizza', 'Soups', 'Salad', 'Other Carrier',
#        'Hot Beverage', 'Other Misc', 'Cash Card', 'Catering'],
#       dtype=object)

# %%
df[df['CategoryDescription'] == 'Footlong']
# Out:
#                         MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0      001E0224E4EDA63D6FED96D59E0C1E76  072D3B76BE58E4553A373AF3206D2CA5
# 6      04420CE325EFCE905A9155CBE6EBC001  72BC117B86F77DF24BEB37C0B191B7B1
# 13     0C3A6213CD81B91180D6876CDFAE7A91  1E739D78994A32D295D9C6B6F2D76025
# 15     0D198D7306F3E8DDBC1FA74578492647  BD5D0AA9CC8C5768029C5AE0D9A61C6D
# 17     0DAB10B5ABEBEC1BE111143391D84AC4  7DABBEA37F73D35E4A63ECCFEDAE5FC4
# ...                                 ...                               ...
# 91414  F9F1230442E345CC6A02D4BDDDC663BF  D6455799836C36B324D804AB16F44038
# 91417  FB80F69C05469259024842973E1A57EE  6F595E24BD9FC5229ED07EA03D7AFD31
# 91418  FBC4EAC3714494D6A7A3718C6B6CA7B8  1B57E1F90649A138DF0AF5CCC4579278
# 91428  FFAD36E06711249D447DCD96121F21CC  32A10A584840FC7DBED1818459A24919
# 91429  FFD5DCAFF2286B45901E4EA8F1928646  D56C9748DFA6D3672EAB8AFA1B9E17AE
#
#       CategoryDescription         DepartmentDescription  \
# ...

# %%
df['DepartmentDescription'].unique()
# Out:
# array(['Footlong Sub                ', 'Fountain Drink 21 oz.       ',
#        '6 Inch Sub                  ', 'Add On 6in Portion          ',
#        'Bottled Drink               ', 'Chips                       ',
#        'Cookies                     ', 'Add On FT Portion           ',
#        'Personal Pizza              ', 'Soup                        ',
#        'Fountain Drink 30 oz.       ', 'FT Portion                  ',
#        'Footlong Flatbread          ', 'Fountain Drink 40 oz.       ',
#        'Salad                       ', 'Mini Sub                    ',
#        'Hot Beverage 12 oz.         ', '6 inch Breakfast Flatbread  ',
#        '6 inch Portion              ', 'Side Items                  ',
#        'Footlong Breakfast          ', '6 inch Breakfast            ',
#        'Cash Card                   ', '6 inch Flatbread            ',
#        'Single Portion              ', 'Hot Beverage 16 oz.         ',
# ...

# %%
df['Description'].unique()
# Out:
# array(['Chickn Strips FtLong                      ',
#        '21oz Fountain Drink                       ',
#        'B.M.T. 6 inch                             ',
#        'Veggie Delite 6 inch                      ',
#        'Avocado Add6in                            ',
#        'Turkey 6 inch                             ',
#        'Spicy Italian FtLong                      ',
#        'Bottled Carbonated Drink                  ',
#        'Chicken Teriyaki 6 inch                   ',
#        'Ham 6 inch                                ',
#        'Chips                                     ',
#        'Turkey FtLong                             ',
#        'Subway Club 6 inch                        ',
#        'Subway Club FtLong                        ',
#        'Turkey Italiano FtLong                    ',
#        'TkyBcnAvo FtLong                          ',
#        'Cookie                                    ',
#        'Chicken Teriyaki FtLong                   ',
# ...

# %%
df[df['DiscountAmount'] < 0]
# Out:
#                         MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 29001  8FA09DB7FC32F8750837DEA594370380  76CBDD389138090A663E9EB6F0ABDDE5
# 29895  981F33755CB678F17666ACDF270B412E  DE1246BF214A32B3313E6DAE0CE83D81
# 43444  29D0F917171EFEFEB21A3B24EA39AE05  3077EDDE25423D35500F3DF3B94CEA8A
# 43798  75846AE40A08A375822FD19395A95864  3077EDDE25423D35500F3DF3B94CEA8A
# 57603  37184C5872A9C0DF748AD2DADE740B46  57AFC6796BA512A3C2C079BBD5AFF365
# 57856  6C76A7741CEE1840FC52198B8DF76242  57AFC6796BA512A3C2C079BBD5AFF365
# 66558  A4A0DCCB0E93E31A1BFE0246B5A11EA3  F475A5C8875E68C5BBC59A2F4FBC17EC
# 69966  A0318DE9050D11A5A42016BA2328C384  4DDE9500CAE6D857B2E3F2BF1D3CBE18
# 70006  AEABCC9226510356E1A5FA6C96050D12  4DDE9500CAE6D857B2E3F2BF1D3CBE18
# 91164  B972812807235523EAEE771C60B2D55C  8724FDCD199FBD4216089677E7789C02
#
#       CategoryDescription         DepartmentDescription  \
# 29001               Salad  Salad
# 29895              Add On  Add On 6in Portion
# ...

# %%
df[df['AdjustedPrice'] < 0]
# Out:
# Empty DataFrame
# Columns: [MD5KEY_MENUITEM, MD5KEY_ORDERSALE, CategoryDescription, DepartmentDescription, Description, StoreNumber, TaxInclusiveAmount, TaxAmount, AdjustedPrice, DiscountAmount, Price, Quantity, PLU, Id, date, SalesAmount]
# Index: []

# %%
df['AdjustedPrice'].describe()
# Out:
# count    91431.000000
# mean         3.464881
# std          3.511239
# min          0.000000
# 25%          1.270000
# 50%          2.100000
# 75%          5.500000
# max        506.250000
# Name: AdjustedPrice, dtype: float64

# %%
df['DiscountAmount'].describe()
# Out:
# count    91431.000000
# mean         0.200753
# std          0.672092
# min         -0.750000
# 25%          0.000000
# 50%          0.000000
# 75%          0.130000
# max         29.250000
# Name: DiscountAmount, dtype: float64

# %%
df['DiscountAmount'].describe()
# Out:
# count    91431.000000
# mean         0.200753
# std          0.672092
# min         -0.750000
# 25%          0.000000
# 50%          0.000000
# 75%          0.130000
# max         29.250000
# Name: DiscountAmount, dtype: float64

# %%
df['SalesAmount'].describe()
# Out:
# count    91431.000000
# mean         4.622352
# std        136.818546
# min          0.000000
# 25%          1.420000
# 50%          2.810000
# 75%          5.500000
# max      37968.750000
# Name: SalesAmount, dtype: float64

# %%
df[df['SalesAmount'] == 37968.750000]
# Out:
#                         MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 63798  7AFF6F9A39CC2CBBD33DFFFDF213DA88  B6BA5DC2E5670B796E57C435A64E8E60
#
#       CategoryDescription         DepartmentDescription  \
# 63798            Footlong  Footlong Sub
#
#                                       Description  StoreNumber  \
# 63798  Turkey FtLong                                      4904
#
#        TaxInclusiveAmount  TaxAmount  AdjustedPrice  DiscountAmount  Price  \
# 63798                   0    43.0312         506.25             0.0   6.75
#
#        Quantity        PLU  Id       date  SalesAmount
# 63798        75  111000012  12 2015-05-16     37968.75

# %%
df['Quantity'].describe()
# Out:
# count    91431.000000
# mean         1.092102
# std          0.534937
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         75.000000
# Name: Quantity, dtype: float64

# %%
df['Price'].describe()
# Out:
# count    91431.000000
# mean         3.473435
# std          2.444280
# min          0.000000
# 25%          1.500000
# 50%          2.100000
# 75%          5.500000
# max         60.000000
# Name: Price, dtype: float64

# %%
df[df['Price'] == 0]
# Out:
#                        MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 5878  2FC3289E8B0FC19A65582C7E80604BD0  3E934D88D60D22BF956CBCF9281513E8
#
#      CategoryDescription         DepartmentDescription  \
# 5878        Hot Beverage  Hot Beverage 12 oz.
#
#                                      Description  StoreNumber  \
# 5878  12oz Coffee                                        4904
#
#       TaxInclusiveAmount  TaxAmount  AdjustedPrice  DiscountAmount  Price  \
# 5878                   0        0.0            0.0             0.0    0.0
#
#       Quantity        PLU   Id       date  SalesAmount
# 5878         1  231000111  613 2015-03-17          0.0

# %%
df['Quantity'].value_counts()
# Out:
# Quantity
# 1     84567
# 2      6136
# 3       425
# 4       204
# 6        31
# 5        28
# 8        15
# 12        5
# 10        5
# 7         5
# 30        2
# 24        1
# 45        1
# 75        1
# 18        1
# 14        1
# 15        1
# 20        1
# 60        1
# Name: count, dtype: int64

# %% [markdown]
# ### Phần trăm discount

# %%
df.columns
# Out:
# Index(['MD5KEY_MENUITEM', 'MD5KEY_ORDERSALE', 'CategoryDescription',
#        'DepartmentDescription', 'Description', 'StoreNumber',
#        'TaxInclusiveAmount', 'TaxAmount', 'AdjustedPrice', 'DiscountAmount',
#        'Price', 'Quantity', 'PLU', 'Id', 'date', 'SalesAmount'],
#       dtype='object')

# %%
# Doanh thu từng cửa hàng
df_store = df.groupby('StoreNumber').agg(revenue=('SalesAmount', 'sum'), count=('StoreNumber', 'count'))
df_store['avg_revenue'] = df_store['revenue'] / df_store['count']
df_store.head()
# Out:
#                revenue  count  avg_revenue
# StoreNumber
# 4904         179129.39  29762     6.018728
# 12631        100905.51  26296     3.837295
# 20974         77244.46  18262     4.229792
# 46673         65346.94  17111     3.819002

# %%
plt.figure(figsize=(16, 8))

sns.lineplot(df,
             x='date',
             y='SalesAmount',
             hue='StoreNumber')

plt.show()

# %% [markdown]
# ## Xử lý khoảng trắng trong các trường object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91431 entries, 0 to 91430
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MD5KEY_MENUITEM        91431 non-null  object
#  1   MD5KEY_ORDERSALE       91431 non-null  object
#  2   CategoryDescription    91431 non-null  object
#  3   DepartmentDescription  91431 non-null  object
#  4   Description            91431 non-null  object
#  5   StoreNumber            91431 non-null  int64
#  6   TaxInclusiveAmount     91431 non-null  int64
#  7   TaxAmount              91431 non-null  float64
#  8   AdjustedPrice          91431 non-null  float64
#  9   DiscountAmount         91431 non-null  float64
#  10  Price                  91431 non-null  float64
#  11  Quantity               91431 non-null  int64
#  12  PLU                    91431 non-null  int64
#  13  Id                     91431 non-null  int64
# ...

# %%
# df['MD5KEY_MENUITEM'].unique()
# df['MD5KEY_ORDERSALE'].unique()
# df['CategoryDescription'].unique()
# df['DepartmentDescription'].unique()
df['Description'].unique()
# Out:
# array(['Chickn Strips FtLong                      ',
#        '21oz Fountain Drink                       ',
#        'B.M.T. 6 inch                             ',
#        'Veggie Delite 6 inch                      ',
#        'Avocado Add6in                            ',
#        'Turkey 6 inch                             ',
#        'Spicy Italian FtLong                      ',
#        'Bottled Carbonated Drink                  ',
#        'Chicken Teriyaki 6 inch                   ',
#        'Ham 6 inch                                ',
#        'Chips                                     ',
#        'Turkey FtLong                             ',
#        'Subway Club 6 inch                        ',
#        'Subway Club FtLong                        ',
#        'Turkey Italiano FtLong                    ',
#        'TkyBcnAvo FtLong                          ',
#        'Cookie                                    ',
#        'Chicken Teriyaki FtLong                   ',
# ...

# %%
df = data_cleaning.remove_whitespace(df)

# %%
# df['Description'].unique()
df['DepartmentDescription'].unique()
# Out:
# array(['Footlong Sub', 'Fountain Drink 21 oz.', '6 Inch Sub',
#        'Add On 6in Portion', 'Bottled Drink', 'Chips', 'Cookies',
#        'Add On FT Portion', 'Personal Pizza', 'Soup',
#        'Fountain Drink 30 oz.', 'FT Portion', 'Footlong Flatbread',
#        'Fountain Drink 40 oz.', 'Salad', 'Mini Sub',
#        'Hot Beverage 12 oz.', '6 inch Breakfast Flatbread',
#        '6 inch Portion', 'Side Items', 'Footlong Breakfast',
#        '6 inch Breakfast', 'Cash Card', '6 inch Flatbread',
#        'Single Portion', 'Hot Beverage 16 oz.',
#        'Footlong Breakfast Flatbread', 'Sandwich Platter', 'Kids Toy',
#        'FT Bkfst Portion', '6 inch Bkfst Portion', 'Add On Pizza', 'Wrap',
#        'Fees and Charges'], dtype=object)

# %% [markdown]
# ## Lưu trữ file sau khi xử lý

# %%
current_date = datetime.now().strftime("%Y%m%d")
parent_dir = "/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed" 

# Tạo đường dẫn đầy đủ cho thư mục mới
new_folder_path = os.path.join(parent_dir, current_date)

# Kiểm tra xem thư mục đã tồn tại chưa, nếu chưa thì tạo mới
if not os.path.exists(new_folder_path):
    os.makedirs(new_folder_path)
    print(f"Thư mục '{new_folder_path}' đã được tạo thành công!")
else:
    print(f"Thư mục '{new_folder_path}' đã tồn tại.")

df.to_csv(f'{new_folder_path}/menuitem_{current_date}.csv', index=False)
# Out:
# Thư mục '/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/20240715' đã tồn tại.
