# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
df = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/raw/recipes.csv')

# %%
df.head()
# Out:
#            RecipeName                           RecipeDescription  RecipeId
# 0  FtL/Ham             Ham FtLong                                         1
# 1  FfB/Ham             Ham FtFbd                                          2
# 2  Six/Ham             Ham 6 inch                                         3
# 3  fBd/Ham             Ham FlatBd                                         4
# 4  Sld/Ham             Ham Salad                                          5

# %%
df.shape
# Out:
# (7458, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7458 entries, 0 to 7457
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   RecipeName         7458 non-null   object
#  1   RecipeDescription  7458 non-null   object
#  2   RecipeId           7458 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 174.9+ KB

# %%
df.isna().sum()
# Out:
# RecipeName           0
# RecipeDescription    0
# RecipeId             0
# dtype: int64

# %%
current_date = datetime.now().strftime('%Y%m%d')   
df.to_csv(f'/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/recipes_{current_date}.csv', index=False)
