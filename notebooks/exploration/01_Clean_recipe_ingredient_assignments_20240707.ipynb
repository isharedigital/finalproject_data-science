# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
df = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/raw/recipe_ingredient_assignments.csv')

# %%
df.head()
# Out:
#    RecipeId  IngredientId  Quantity
# 0         2             7         4
# 1         6             7         4
# 2         7             7         2
# 3         8             7         2
# 4         9             7         2

# %%
df.shape
# Out:
# (14308, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14308 entries, 0 to 14307
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RecipeId      14308 non-null  int64
#  1   IngredientId  14308 non-null  int64
#  2   Quantity      14308 non-null  int64
# dtypes: int64(3)
# memory usage: 335.5 KB

# %%
df.isna().sum()
# Out:
# RecipeId        0
# IngredientId    0
# Quantity        0
# dtype: int64

# %%
current_date = datetime.now().strftime('%Y%m%d')   
df.to_csv(f'/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/recipe_ingredient_assignments_{current_date}.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14308 entries, 0 to 14307
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RecipeId      14308 non-null  int64
#  1   IngredientId  14308 non-null  int64
#  2   Quantity      14308 non-null  int64
# dtypes: int64(3)
# memory usage: 335.5 KB
