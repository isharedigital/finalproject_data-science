# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import sys
import os
sys.path.append('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/scripts/')
import data_cleaning

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
df = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/raw/sub_recipes.csv')

# %%
df.head()
# Out:
#                                        SubRecipeName  \
# 0  Std Footlong Sub bread
# 1  Std 6 Inch Sub bread
# 2  Std Footlong Flatbread Bread
# 3  Std 6 Inch Flatbread bread
# 4  Std Salad Lettuce, bowl, & dressing
#
#                                 SubRecipeDescription  SubRecipeId
# 0  Std Footlong Sub Bread                                       1
# 1  Std 6 Inch Sub Bread                                         2
# 2  Std Footlong Flatbread Bread                                 3
# 3  Std 6 Inch Flatbread bread                                   4
# 4  Std Salad Lettuce, Bowl & Dressing                           5

# %%
df.shape
# Out:
# (81, 3)

# %%
df['SubRecipeName'].value_counts()
# Out:
# SubRecipeName
# Std Footlong Sub bread                               1
# Vegetables - Metric,                                 1
# Std 6-Inch Sub bread-Bahamas                         1
# Sliced Cheese-Bahamas                                1
# Std Salad lettuce, bowl, & dressing-Bahamas          1
#                                                     ..
# Std Breakfast 6 inch Flatbread Liquid Egg            1
# Std Breakfast FL Flatbread Liquid egg                1
# Std Breakfast 6 inch liquid egg                      1
# Std breakfast footlong liquid egg                    1
# Std Breakfast Wrap Bread plus egg mayo               1
# Name: count, Length: 81, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SubRecipeName         81 non-null     object
#  1   SubRecipeDescription  81 non-null     object
#  2   SubRecipeId           81 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 2.0+ KB

# %%
df.isna().sum()
# Out:
# SubRecipeName           0
# SubRecipeDescription    0
# SubRecipeId             0
# dtype: int64

# %% [markdown]
# ## Xử lý khoảng trắng các cột object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SubRecipeName         81 non-null     object
#  1   SubRecipeDescription  81 non-null     object
#  2   SubRecipeId           81 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 2.0+ KB

# %%
df['SubRecipeName'].unique()
df['SubRecipeDescription'].unique()
# Out:
# array(['Std Footlong Sub Bread                           ',
#        'Std 6 Inch Sub Bread                             ',
#        'Std Footlong Flatbread Bread                     ',
#        'Std 6 Inch Flatbread bread                       ',
#        'Std Salad Lettuce, Bowl & Dressing               ',
#        'Std Footlong Vegetables DELETE                   ',
#        'Std 6 Inch Vegetables                            ',
#        'Std Sliced Cheese DELETE                         ',
#        'Sliced Cheese                                    ',
#        'Vegetables                                       ',
#        'Std 6 -Inch Sub Bread                            ',
#        'Sauces, core sauces                              ',
#        'Std Mini Sub bread                               ',
#        'Std English Muffin Bread                         ',
#        'Std Breakfast FL Bread & Egg                     ',
#        'Std Breakfast 6 inch Bread & Egg                 ',
# ...

# %%
df = data_cleaning.remove_whitespace(df)

# %%
df['SubRecipeName'].unique()
df['SubRecipeDescription'].unique()
# Out:
# array(['Std Footlong Sub Bread', 'Std 6 Inch Sub Bread',
#        'Std Footlong Flatbread Bread', 'Std 6 Inch Flatbread bread',
#        'Std Salad Lettuce, Bowl & Dressing',
#        'Std Footlong Vegetables DELETE', 'Std 6 Inch Vegetables',
#        'Std Sliced Cheese DELETE', 'Sliced Cheese', 'Vegetables',
#        'Std 6 -Inch Sub Bread', 'Sauces, core sauces',
#        'Std Mini Sub bread', 'Std English Muffin Bread',
#        'Std Breakfast FL Bread & Egg', 'Std Breakfast 6 inch Bread & Egg',
#        'Std Breakfast Flatbread FL & Egg',
#        'Std Breakfast 6 Inch Flatbread & Egg',
#        'Std Breakfast 3 inch Flatbread & Egg',
#        'Std Breakfast Biscuit & egg', 'Std Breakfast Croissant & Egg',
#        'Std Subway to Go! Pkg, chips & cookie',
#        'Std English muffin with liquid egg omelet program',
#        'Std breakfast footlong liquid egg omelet',
#        'Std Breakfast 6 inch liquid egg omelet',
#        'Std Bkfst FL Flatbread Liquid Egg Omelet',
# ...

# %% [markdown]
# ## Lưu trữ file sau khi xử lý

# %%
# current_date = datetime.now().strftime('%Y%m%d')   
# df.to_csv(f'/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/sub_recipes_{current_date}.csv', index=False)

current_date = datetime.now().strftime("%Y%m%d")
parent_dir = "/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed" 

# Tạo đường dẫn đầy đủ cho thư mục mới
new_folder_path = os.path.join(parent_dir, current_date)

# Kiểm tra xem thư mục đã tồn tại chưa, nếu chưa thì tạo mới
if not os.path.exists(new_folder_path):
    os.makedirs(new_folder_path)
    print(f"Thư mục '{new_folder_path}' đã được tạo thành công!")
else:
    print(f"Thư mục '{new_folder_path}' đã tồn tại.")

df.to_csv(f'{new_folder_path}/sub_recipes_{current_date}.csv', index=False)
# Out:
# Thư mục '/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/20240715' đã tồn tại.
