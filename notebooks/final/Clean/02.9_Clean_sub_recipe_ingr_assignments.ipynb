# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import sys
import os
sys.path.append('../../../scripts/')
import data_cleaning

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv("../../../data/raw/sub_recipe_ingr_assignments.csv")

# %%
df.head()
# Out:
#    SubRecipeId  IngredientId  Quantity
# 0            1             1         1
# 1            1           135         2
# 2            1           138         1
# 3            1           146         1
# 4            1           157         1

# %% [markdown]
# # 1. Kiểm tra kiểu dữ liệu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SubRecipeId   379 non-null    int64
#  1   IngredientId  379 non-null    int64
#  2   Quantity      379 non-null    int64
# dtypes: int64(3)
# memory usage: 9.0 KB

# %% [markdown]
# # 2. Kiểm tra giá trị thiếu

# %%
df.isna().sum()
# Out:
# SubRecipeId     0
# IngredientId    0
# Quantity        0
# dtype: int64

# %% [markdown]
# # 3. Kiểm tra trùng lặp

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 4. Lưu trữ dữ liệu

# %%
# current_date = datetime.now().strftime("%Y%m%d")
# parent_dir = "../../../data/processed" 

# # Tạo đường dẫn đầy đủ cho thư mục mới
# new_folder_path = os.path.join(parent_dir, current_date)

# # Kiểm tra xem thư mục đã tồn tại chưa, nếu chưa thì tạo mới
# if not os.path.exists(new_folder_path):
#     os.makedirs(new_folder_path)
#     print(f"Thư mục '{new_folder_path}' đã được tạo thành công!")
# else:
#     print(f"Thư mục '{new_folder_path}' đã tồn tại.")

# df.to_csv(f'{new_folder_path}/9.sub_recipe_ingr_assignments_{current_date}.csv', index=False)
# Out:
# Thư mục '../../../data/processed/20240722' đã tồn tại.
