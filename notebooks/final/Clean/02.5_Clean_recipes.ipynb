# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import sys
import os
sys.path.append('../../../scripts/')
import data_cleaning

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv("../../../data/raw/recipes.csv")

# %%
df.head()
# Out:
#            RecipeName                           RecipeDescription  RecipeId
# 0  FtL/Ham             Ham FtLong                                         1
# 1  FfB/Ham             Ham FtFbd                                          2
# 2  Six/Ham             Ham 6 inch                                         3
# 3  fBd/Ham             Ham FlatBd                                         4
# 4  Sld/Ham             Ham Salad                                          5

# %% [markdown]
# # 1. Kiểm tra kiểu dữ liệu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7458 entries, 0 to 7457
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   RecipeName         7458 non-null   object
#  1   RecipeDescription  7458 non-null   object
#  2   RecipeId           7458 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 174.9+ KB

# %% [markdown]
# # 2. Kiểm tra khoảng trắng

# %% [markdown]
# ## 2.1 Kiểm tra

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['RecipeName', 'RecipeDescription'], dtype='object')

# %%
df['RecipeName'].unique()
# Out:
# array(['FtL/Ham           ', 'FfB/Ham           ', 'Six/Ham           ',
#        ..., 'TCBY/WafCne       ', 'TCBY/SmShiv       ',
#        'FBx/TkyAvo        '], dtype=object)

# %% [markdown]
# ## 2.2 Xử lý

# %%
df = data_cleaning.remove_whitespace(df)

# %%
# df['RecipeName'].unique()
df['RecipeDescription'].unique()
# Out:
# array(['Ham FtLong', 'Ham FtFbd', 'Ham 6 inch', ..., 'Waffle Cone TCBY',
#        'Small Shivers TCBY', 'Tky Avocado FBxLun'], dtype=object)

# %% [markdown]
# # 3. Kiểm tra giá tri thiếu

# %%
df.isna().sum()
# Out:
# RecipeName           0
# RecipeDescription    0
# RecipeId             0
# dtype: int64

# %% [markdown]
# # 4. Kiểm tra trùng lặp

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 5.Lưu trữ dữ liệu

# %%
# current_date = datetime.now().strftime("%Y%m%d")
# parent_dir = "../../../data/processed" 

# # Tạo đường dẫn đầy đủ cho thư mục mới
# new_folder_path = os.path.join(parent_dir, current_date)

# # Kiểm tra xem thư mục đã tồn tại chưa, nếu chưa thì tạo mới
# if not os.path.exists(new_folder_path):
#     os.makedirs(new_folder_path)
#     print(f"Thư mục '{new_folder_path}' đã được tạo thành công!")
# else:
#     print(f"Thư mục '{new_folder_path}' đã tồn tại.")

# df.to_csv(f'{new_folder_path}/5.recipes_{current_date}.csv', index=False)
# Out:
# Thư mục '../../../data/processed/20240722' đã tồn tại.
