# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import sys
import os
sys.path.append('../../../scripts/')
import data_cleaning

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv("../../../data/raw/recipe_ingredient_assignments.csv")

# %%
df.head()
# Out:
#    RecipeId  IngredientId  Quantity
# 0         2             7         4
# 1         6             7         4
# 2         7             7         2
# 3         8             7         2
# 4         9             7         2

# %% [markdown]
# # 1. Kiểm tra kiểu dữ liệu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14308 entries, 0 to 14307
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RecipeId      14308 non-null  int64
#  1   IngredientId  14308 non-null  int64
#  2   Quantity      14308 non-null  int64
# dtypes: int64(3)
# memory usage: 335.5 KB
