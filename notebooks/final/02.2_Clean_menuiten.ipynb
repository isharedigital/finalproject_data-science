# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import sys
import os
sys.path.append('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/scripts/')
import data_cleaning

# %%
df = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/raw/menuitem.csv')

# %%
df.head()
# Out:
#                     MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0  001E0224E4EDA63D6FED96D59E0C1E76  072D3B76BE58E4553A373AF3206D2CA5
# 1  003E4E20196B2F5BDD33CE06D2943EF4  14811D4F3458058007B0B6908C2DA393
# 2  012A55E5551C95A559A7B074AE85117E  22FA6C39B7A15ABB6EB568E66A6B30E1
# 3  01B07F1C6DC6945796571FC78735DA16  915B69612845BBD974C39AC105F5CA8C
# 4  02DE19974DE5304BF243A1C2EC639495  CD6386C802450EDCF13A3D112D1F86EC
#
#   CategoryDescription         DepartmentDescription  \
# 0    Footlong          Footlong Sub
# 1    Fountain          Fountain Drink 21 oz.
# 2    6 Inch            6 Inch Sub
# 3    6 Inch            6 Inch Sub
# 4    Add On            Add On 6in Portion
#
#                                   Description  StoreNumber  \
# 0  Chickn Strips FtLong                              46673
# 1  21oz Fountain Drink                               46673
# 2  B.M.T. 6 inch                                     12631
# 3  Veggie Delite 6 inch                              12631
# 4  Avocado Add6in                                    12631
#
#    TaxInclusiveAmount  TaxAmount  AdjustedPrice  DiscountAmount  Price  \
# 0                   0     0.6975           7.75            0.00   7.75
# 1                   0     0.1530           1.70            0.00   1.70
# 2                   0     0.3230           3.64            0.61   4.25
# 3                   0     0.3328           3.75            0.00   3.75
# 4                   0     0.0443           0.50            0.00   0.50
#
#    Quantity        PLU   Id      date
# 0         1  111000041  326  15-03-05
# 1         1  212000126  280  15-03-05
# 2         1  121000008    8  15-03-05
# 3         1  121000001   91  15-03-05
# 4         1  175000062  564  15-03-05

# %% [markdown]
# # 1. Check và xử lý kiểu dữ liệu

# %% [markdown]
# ## Kiểm tra

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91431 entries, 0 to 91430
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MD5KEY_MENUITEM        91431 non-null  object
#  1   MD5KEY_ORDERSALE       91431 non-null  object
#  2   CategoryDescription    91431 non-null  object
#  3   DepartmentDescription  91431 non-null  object
#  4   Description            91431 non-null  object
#  5   StoreNumber            91431 non-null  int64
#  6   TaxInclusiveAmount     91431 non-null  int64
#  7   TaxAmount              91431 non-null  float64
#  8   AdjustedPrice          91431 non-null  float64
#  9   DiscountAmount         91431 non-null  float64
#  10  Price                  91431 non-null  float64
#  11  Quantity               91431 non-null  int64
#  12  PLU                    91431 non-null  int64
#  13  Id                     91431 non-null  int64
#  14  date                   91431 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 10.5+ MB

# %% [markdown]
# ## Xử lý
# - date chuyển đổi kiểu dữ liệu object sang datetime

# %%
# Convert the date column to the datetime data type
df['date'] = pd.to_datetime(df['date'], format='%y-%m-%d')

# %%
df.head()
# Out:
#                     MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0  001E0224E4EDA63D6FED96D59E0C1E76  072D3B76BE58E4553A373AF3206D2CA5
# 1  003E4E20196B2F5BDD33CE06D2943EF4  14811D4F3458058007B0B6908C2DA393
# 2  012A55E5551C95A559A7B074AE85117E  22FA6C39B7A15ABB6EB568E66A6B30E1
# 3  01B07F1C6DC6945796571FC78735DA16  915B69612845BBD974C39AC105F5CA8C
# 4  02DE19974DE5304BF243A1C2EC639495  CD6386C802450EDCF13A3D112D1F86EC
#
#   CategoryDescription         DepartmentDescription  \
# 0    Footlong          Footlong Sub
# 1    Fountain          Fountain Drink 21 oz.
# 2    6 Inch            6 Inch Sub
# 3    6 Inch            6 Inch Sub
# 4    Add On            Add On 6in Portion
#
#                                   Description  StoreNumber  \
# 0  Chickn Strips FtLong                              46673
# 1  21oz Fountain Drink                               46673
# 2  B.M.T. 6 inch                                     12631
# 3  Veggie Delite 6 inch                              12631
# 4  Avocado Add6in                                    12631
#
#    TaxInclusiveAmount  TaxAmount  AdjustedPrice  DiscountAmount  Price  \
# 0                   0     0.6975           7.75            0.00   7.75
# 1                   0     0.1530           1.70            0.00   1.70
# 2                   0     0.3230           3.64            0.61   4.25
# 3                   0     0.3328           3.75            0.00   3.75
# 4                   0     0.0443           0.50            0.00   0.50
#
#    Quantity        PLU   Id       date
# 0         1  111000041  326 2015-03-05
# 1         1  212000126  280 2015-03-05
# 2         1  121000008    8 2015-03-05
# 3         1  121000001   91 2015-03-05
# 4         1  175000062  564 2015-03-05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91431 entries, 0 to 91430
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MD5KEY_MENUITEM        91431 non-null  object
#  1   MD5KEY_ORDERSALE       91431 non-null  object
#  2   CategoryDescription    91431 non-null  object
#  3   DepartmentDescription  91431 non-null  object
#  4   Description            91431 non-null  object
#  5   StoreNumber            91431 non-null  int64
#  6   TaxInclusiveAmount     91431 non-null  int64
#  7   TaxAmount              91431 non-null  float64
#  8   AdjustedPrice          91431 non-null  float64
#  9   DiscountAmount         91431 non-null  float64
#  10  Price                  91431 non-null  float64
#  11  Quantity               91431 non-null  int64
#  12  PLU                    91431 non-null  int64
#  13  Id                     91431 non-null  int64
#  14  date                   91431 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(5), object(5)
# memory usage: 10.5+ MB

# %% [markdown]
# # Kiểm tra và xử lý khoảng trắng

# %% [markdown]
# ## Kiểm tra

# %%
df.select_dtypes(include="object")
# Out:
#                         MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0      001E0224E4EDA63D6FED96D59E0C1E76  072D3B76BE58E4553A373AF3206D2CA5
# 1      003E4E20196B2F5BDD33CE06D2943EF4  14811D4F3458058007B0B6908C2DA393
# 2      012A55E5551C95A559A7B074AE85117E  22FA6C39B7A15ABB6EB568E66A6B30E1
# 3      01B07F1C6DC6945796571FC78735DA16  915B69612845BBD974C39AC105F5CA8C
# 4      02DE19974DE5304BF243A1C2EC639495  CD6386C802450EDCF13A3D112D1F86EC
# ...                                 ...                               ...
# 91426  FF8D9C582D9D56B98033132538E0020A  C1FC597609722C265C130E692875AF96
# 91427  FFAA204DCDF43F43ADF7BD6AFCFEAC7A  6328756C8846E3534E92659812D54C64
# 91428  FFAD36E06711249D447DCD96121F21CC  32A10A584840FC7DBED1818459A24919
# 91429  FFD5DCAFF2286B45901E4EA8F1928646  D56C9748DFA6D3672EAB8AFA1B9E17AE
# 91430  FFD8B07B8FA33273EAA2B78FD3E6BE71  3C02CD72C1C06499E64F739493459C14
#
#       CategoryDescription         DepartmentDescription  \
# 0        Footlong          Footlong Sub
# 1        Fountain          Fountain Drink 21 oz.
# 2        6 Inch            6 Inch Sub
# 3        6 Inch            6 Inch Sub
# 4        Add On            Add On 6in Portion
# ...                   ...                           ...
# 91426    Chips             Chips
# 91427    6 Inch            6 Inch Sub
# 91428    Footlong          Footlong Sub
# 91429    Footlong          Footlong Sub
# 91430    Fountain          Fountain Drink 21 oz.
#
#                                       Description
# 0      Chickn Strips FtLong
# 1      21oz Fountain Drink
# 2      B.M.T. 6 inch
# 3      Veggie Delite 6 inch
# 4      Avocado Add6in
# ...                                           ...
# 91426  Chips
# 91427  Cold Cut Combo 6 inch
# 91428  Cold Cut Combo FtLong
# 91429  Spicy Italian FtLong
# 91430  21oz Fountain Drink
#
# [91431 rows x 5 columns]

# %%
df['CategoryDescription'].str.contains(r'^\s+|\s+$').sum()
# Out:
# 82679

# %%
df.shape
# Out:
# (91431, 15)

# %% [markdown]
# ## Xử lý

# %%
df = data_cleaning.remove_whitespace(df)

# %%
df['CategoryDescription'].str.contains(r'^\s+|\s+$').sum()
# Out:
# 0

# %% [markdown]
# # Kiểm tra xử lý giá trị thiếu

# %% [markdown]
# ## Kiểm tra

# %%
df.isna().sum()
# Out:
# MD5KEY_MENUITEM          0
# MD5KEY_ORDERSALE         0
# CategoryDescription      0
# DepartmentDescription    0
# Description              0
# StoreNumber              0
# TaxInclusiveAmount       0
# TaxAmount                0
# AdjustedPrice            0
# DiscountAmount           0
# Price                    0
# Quantity                 0
# PLU                      0
# Id                       0
# date                     0
# dtype: int64

# %% [markdown]
# # Kiểm tra và loại bỏ giá trị trùng lặp

# %% [markdown]
# ## Kiểm tra

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Thêm - Tạo thêm trường SalesAmount, day_of_week
# - Data chưa có cột SalesAmount, tạo thêm để phân tích doanh thu -> Giá sau trừ giảm giá * số lượng
# - Tạo thêm trường day_of_week để phân tích ngày có doanh thu tốt và kém trong tuần

# %%
df['SalesAmount'] = df['AdjustedPrice'] * df['Quantity']
df['day_of_week'] = df['date'].dt.day_name()

# %%
df.head()
# Out:
#                     MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0  001E0224E4EDA63D6FED96D59E0C1E76  072D3B76BE58E4553A373AF3206D2CA5
# 1  003E4E20196B2F5BDD33CE06D2943EF4  14811D4F3458058007B0B6908C2DA393
# 2  012A55E5551C95A559A7B074AE85117E  22FA6C39B7A15ABB6EB568E66A6B30E1
# 3  01B07F1C6DC6945796571FC78735DA16  915B69612845BBD974C39AC105F5CA8C
# 4  02DE19974DE5304BF243A1C2EC639495  CD6386C802450EDCF13A3D112D1F86EC
#
#   CategoryDescription  DepartmentDescription           Description  \
# 0            Footlong           Footlong Sub  Chickn Strips FtLong
# 1            Fountain  Fountain Drink 21 oz.   21oz Fountain Drink
# 2              6 Inch             6 Inch Sub         B.M.T. 6 inch
# 3              6 Inch             6 Inch Sub  Veggie Delite 6 inch
# 4              Add On     Add On 6in Portion        Avocado Add6in
#
#    StoreNumber  TaxInclusiveAmount  TaxAmount  AdjustedPrice  DiscountAmount  \
# 0        46673                   0     0.6975           7.75            0.00
# 1        46673                   0     0.1530           1.70            0.00
# 2        12631                   0     0.3230           3.64            0.61
# 3        12631                   0     0.3328           3.75            0.00
# 4        12631                   0     0.0443           0.50            0.00
#
#    Price  Quantity        PLU   Id       date  SalesAmount day_of_week
# 0   7.75         1  111000041  326 2015-03-05         7.75    Thursday
# 1   1.70         1  212000126  280 2015-03-05         1.70    Thursday
# 2   4.25         1  121000008    8 2015-03-05         3.64    Thursday
# 3   3.75         1  121000001   91 2015-03-05         3.75    Thursday
# 4   0.50         1  175000062  564 2015-03-05         0.50    Thursday

# %%
df['day_of_week'].value_counts()
# Out:
# day_of_week
# Monday       14371
# Sunday       14265
# Wednesday    14254
# Thursday     14131
# Tuesday      13678
# Friday       11569
# Saturday      9163
# Name: count, dtype: int64

# %% [markdown]
# # Kiểm tra và xử lý giá trị ngoại lai

# %% [markdown]
# ## Kiểm tra tổng quan

# %%
df_boxplt = df[['TaxAmount', 'AdjustedPrice', 'DiscountAmount', 'Price', 'Quantity']]

# Tạo figure và các axes con với 3 hàng và 2 cột
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Vẽ từng boxplot vào từng subplot riêng biệt
for ax, column in zip(axes, df_boxplt):
    df.boxplot(column=column, ax=ax)
    ax.set_title(f'Boxplot of {column}')
    ax.set_xlabel('Columns')
    ax.set_ylabel('Values')

# Ẩn các subplot không sử dụng nếu có
for i in range(len(df_boxplt), len(axes)):
    fig.delaxes(axes[i])

# Tối ưu khoảng cách giữa các subplot
plt.tight_layout()
plt.show()

# %%
df.select_dtypes(include='number').describe()
# Out:
#         StoreNumber  TaxInclusiveAmount     TaxAmount  AdjustedPrice  \
# count  91431.000000             91431.0  91431.000000   91431.000000
# mean   18152.995319                 0.0      0.263194       3.464881
# std    14823.097615                 0.0      0.291208       3.511239
# min     4904.000000                 0.0      0.000000       0.000000
# 25%     4904.000000                 0.0      0.094900       1.270000
# 50%    12631.000000                 0.0      0.150700       2.100000
# 75%    20974.000000                 0.0      0.444700       5.500000
# max    46673.000000                 0.0     43.031200     506.250000
#
#        DiscountAmount         Price      Quantity           PLU            Id  \
# count    91431.000000  91431.000000  91431.000000  9.143100e+04  91431.000000
# mean         0.200753      3.473435      1.092102  1.889488e+08    371.846048
# std          0.672092      2.444280      0.534937  8.030443e+07   1078.178157
# min         -0.750000      0.000000      1.000000  1.110000e+08      1.000000
# 25%          0.000000      1.500000      1.000000  1.120000e+08     64.000000
# 50%          0.000000      2.100000      1.000000  1.740000e+08    276.000000
# 75%          0.130000      5.500000      1.000000  2.210001e+08    280.000000
# max         29.250000     60.000000     75.000000  4.110002e+08  10067.000000
#
#         SalesAmount
# count  91431.000000
# mean       4.622352
# std      136.818546
# min        0.000000
# 25%        1.420000
# 50%        2.810000
# 75%        5.500000
# max    37968.750000

# %% [markdown]
# ## Kiểm tra và xử lý sản phẩm giá bằng 0

# %% [markdown]
# ### Kiểm tra

# %%
df[df['Price'] == 0]
# Out:
#                        MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 5878  2FC3289E8B0FC19A65582C7E80604BD0  3E934D88D60D22BF956CBCF9281513E8
#
#      CategoryDescription DepartmentDescription  Description  StoreNumber  \
# 5878        Hot Beverage   Hot Beverage 12 oz.  12oz Coffee         4904
#
#       TaxInclusiveAmount  TaxAmount  AdjustedPrice  DiscountAmount  Price  \
# 5878                   0        0.0            0.0             0.0    0.0
#
#       Quantity        PLU   Id       date  SalesAmount day_of_week
# 5878         1  231000111  613 2015-03-17          0.0     Tuesday

# %%
df.shape
# Out:
# (91431, 17)

# %%
df.select_dtypes(include='number').describe()
# Out:
#         StoreNumber  TaxInclusiveAmount     TaxAmount  AdjustedPrice  \
# count  91431.000000             91431.0  91431.000000   91431.000000
# mean   18152.995319                 0.0      0.263194       3.464881
# std    14823.097615                 0.0      0.291208       3.511239
# min     4904.000000                 0.0      0.000000       0.000000
# 25%     4904.000000                 0.0      0.094900       1.270000
# 50%    12631.000000                 0.0      0.150700       2.100000
# 75%    20974.000000                 0.0      0.444700       5.500000
# max    46673.000000                 0.0     43.031200     506.250000
#
#        DiscountAmount         Price      Quantity           PLU            Id  \
# count    91431.000000  91431.000000  91431.000000  9.143100e+04  91431.000000
# mean         0.200753      3.473435      1.092102  1.889488e+08    371.846048
# std          0.672092      2.444280      0.534937  8.030443e+07   1078.178157
# min         -0.750000      0.000000      1.000000  1.110000e+08      1.000000
# 25%          0.000000      1.500000      1.000000  1.120000e+08     64.000000
# 50%          0.000000      2.100000      1.000000  1.740000e+08    276.000000
# 75%          0.130000      5.500000      1.000000  2.210001e+08    280.000000
# max         29.250000     60.000000     75.000000  4.110002e+08  10067.000000
#
#         SalesAmount
# count  91431.000000
# mean       4.622352
# std      136.818546
# min        0.000000
# 25%        1.420000
# 50%        2.810000
# 75%        5.500000
# max    37968.750000

# %%
df[df['AdjustedPrice'] == 0]
# Out:
#                         MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 35     16EF75E36495C66CCC86A0A156C79C2F  2153ABB98FA1E8BF9B4939C0B01D59D0
# 72     26DE03952905774B80F554AC09922E77  F844771B528B904CF6D595EC9106BCAD
# 234    8EE236ECC7F3F40BFC1BF5E182821230  C051C2C48CB7799D5E86FE2EFA296612
# 322    CB8A3434B0C80C6E7A86FF19D6E546F7  2153ABB98FA1E8BF9B4939C0B01D59D0
# 493    4C01362FAE853002658ACDF935BFEC34  7E9638C65F732FD121D72B58367C3069
# ...                                 ...                               ...
# 90765  5EAA15F8C1E5A8D0C2F9D107C7116FE3  A2994A0BECCD0440BC194FFB258D4CBD
# 91035  9B1B977D3A818333AA03C9B5FF4ECBA0  5059840AF45104406D15E97E825927C9
# 91105  AB63CC56211C6003DADE1AFC12C9AEB0  F31FDE7562CAE97FC177208C5594ABFE
# 91213  CA133BE10079232FD9E60084E6436093  54BE7198AE17A23E983F06B6B0F5332A
# 91365  ED94E2C663545DD0A0A9BF6B32D62821  2828E35E92F9B075279A9DA13A30B603
#
#       CategoryDescription DepartmentDescription          Description  \
# 35                Cookies               Cookies               Cookie
# 72               Footlong          Footlong Sub        Turkey FtLong
# 234              Footlong          Footlong Sub  Steak & Chse FtLong
# 322                6 Inch            6 Inch Sub  Steak & Chse 6 inch
# 493               Cookies               Cookies               Cookie
# ...                   ...                   ...                  ...
# 90765              6 Inch            6 Inch Sub  Chicken Parm 6 inch
# 91035            Footlong          Footlong Sub        Turkey FtLong
# 91105            Footlong          Footlong Sub      Meatball FtLong
# 91213             Cookies               Cookies               Cookie
# 91365              6 Inch      6 inch Flatbread  Steak & Chse FlatBd
#
#        StoreNumber  TaxInclusiveAmount  TaxAmount  AdjustedPrice  \
# 35           12631                   0        0.0            0.0
# 72           12631                   0        0.0            0.0
# 234          12631                   0        0.0            0.0
# 322          12631                   0        0.0            0.0
# 493          12631                   0        0.0            0.0
# ...            ...                 ...        ...            ...
# 90765        20974                   0        0.0            0.0
# 91035        20974                   0        0.0            0.0
# 91105        12631                   0        0.0            0.0
# 91213        20974                   0        0.0            0.0
# 91365         4904                   0        0.0            0.0
#
#        DiscountAmount  Price  Quantity        PLU   Id       date  \
# 35               0.60   0.60         1  321000101  276 2015-03-05
# 72               6.50   6.50         1  111000012   12 2015-03-05
# 234              7.25   7.25         1  111000050   85 2015-03-05
# 322              4.50   4.50         1  121000050   86 2015-03-05
# 493              0.55   0.55         1  321000101  276 2015-03-06
# ...               ...    ...       ...        ...  ...        ...
# 90765            4.50   4.50         1  121000073  107 2015-06-15
# 91035            6.75   6.75         1  111000012   12 2015-06-15
# 91105            5.50   5.50         1  111000003   58 2015-06-15
# 91213            1.30   0.65         2  321000101  276 2015-06-15
# 91365            5.00   5.00         1  122000050   88 2015-06-15
#
#        SalesAmount day_of_week
# 35             0.0    Thursday
# 72             0.0    Thursday
# 234            0.0    Thursday
# 322            0.0    Thursday
# 493            0.0      Friday
# ...            ...         ...
# 90765          0.0      Monday
# 91035          0.0      Monday
# 91105          0.0      Monday
# 91213          0.0      Monday
# 91365          0.0      Monday
#
# [1300 rows x 17 columns]

# %% [markdown]
# ### Xử lý
# Chỉ có 1 giá trị duy nhất có thể loại bỏ

# %%
df = df[df['Price'] != 0]

# %%
df[df['Price'] == 0]
# Out:
# Empty DataFrame
# Columns: [MD5KEY_MENUITEM, MD5KEY_ORDERSALE, CategoryDescription, DepartmentDescription, Description, StoreNumber, TaxInclusiveAmount, TaxAmount, AdjustedPrice, DiscountAmount, Price, Quantity, PLU, Id, date, SalesAmount, day_of_week]
# Index: []

# %%
df.shape
# Out:
# (91430, 17)

# %% [markdown]
# ## Check describe sau khi loại bỏ giá bằng 0

# %%
df.select_dtypes(include='number').describe()
# Out:
#         StoreNumber  TaxInclusiveAmount     TaxAmount  AdjustedPrice  \
# count  91430.000000             91430.0  91430.000000   91430.000000
# mean   18153.140227                 0.0      0.263197       3.464919
# std    14823.113917                 0.0      0.291208       3.511240
# min     4904.000000                 0.0      0.000000       0.000000
# 25%     4904.000000                 0.0      0.094900       1.270000
# 50%    12631.000000                 0.0      0.150700       2.100000
# 75%    20974.000000                 0.0      0.444700       5.500000
# max    46673.000000                 0.0     43.031200     506.250000
#
#        DiscountAmount         Price      Quantity           PLU            Id  \
# count    91430.000000  91430.000000  91430.000000  9.143000e+04  91430.000000
# mean         0.200755      3.473473      1.092103  1.889484e+08    371.843410
# std          0.672095      2.444266      0.534940  8.030474e+07   1078.183758
# min         -0.750000      0.050000      1.000000  1.110000e+08      1.000000
# 25%          0.000000      1.500000      1.000000  1.120000e+08     64.000000
# 50%          0.000000      2.100000      1.000000  1.740000e+08    276.000000
# 75%          0.130000      5.500000      1.000000  2.210001e+08    280.000000
# max         29.250000     60.000000     75.000000  4.110002e+08  10067.000000
#
#         SalesAmount
# count  91430.000000
# mean       4.622403
# std      136.819293
# min        0.000000
# 25%        1.420000
# 50%        2.830000
# 75%        5.500000
# max    37968.750000

# %% [markdown]
# ## Kiểm tra và xử lý giá trị DiscountAmount nhỏ hơn 0

# %%
df[df['DiscountAmount'] < 0]
# Out:
#                         MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 29001  8FA09DB7FC32F8750837DEA594370380  76CBDD389138090A663E9EB6F0ABDDE5
# 29895  981F33755CB678F17666ACDF270B412E  DE1246BF214A32B3313E6DAE0CE83D81
# 43444  29D0F917171EFEFEB21A3B24EA39AE05  3077EDDE25423D35500F3DF3B94CEA8A
# 43798  75846AE40A08A375822FD19395A95864  3077EDDE25423D35500F3DF3B94CEA8A
# 57603  37184C5872A9C0DF748AD2DADE740B46  57AFC6796BA512A3C2C079BBD5AFF365
# 57856  6C76A7741CEE1840FC52198B8DF76242  57AFC6796BA512A3C2C079BBD5AFF365
# 66558  A4A0DCCB0E93E31A1BFE0246B5A11EA3  F475A5C8875E68C5BBC59A2F4FBC17EC
# 69966  A0318DE9050D11A5A42016BA2328C384  4DDE9500CAE6D857B2E3F2BF1D3CBE18
# 70006  AEABCC9226510356E1A5FA6C96050D12  4DDE9500CAE6D857B2E3F2BF1D3CBE18
# 91164  B972812807235523EAEE771C60B2D55C  8724FDCD199FBD4216089677E7789C02
#
#       CategoryDescription DepartmentDescription        Description  \
# 29001               Salad                 Salad  Rst Chicken Salad
# 29895              Add On    Add On 6in Portion     Avocado Add6in
# 43444    Bottled Beverage         Bottled Drink      Bottled Water
# 43798               Chips                 Chips              Chips
# 57603    Bottled Beverage         Bottled Drink      Bottled Water
# 57856               Chips                 Chips              Chips
# 66558               Chips                 Chips              Chips
# 69966               Chips                 Chips              Chips
# 70006    Bottled Beverage         Bottled Drink      Bottled Water
# 91164               Chips                 Chips              Chips
#
#        StoreNumber  TaxInclusiveAmount  TaxAmount  AdjustedPrice  \
# 29001        12631                   0        0.0           6.75
# 29895        20974                   0        0.0           1.50
# 43444        12631                   0        0.0           1.61
# 43798        12631                   0        0.0           1.14
# 57603        12631                   0        0.0           1.61
# 57856        12631                   0        0.0           1.14
# 66558        12631                   0        0.0           1.14
# 69966        12631                   0        0.0           1.14
# 70006        12631                   0        0.0           1.56
# 91164        12631                   0        0.0           1.14
#
#        DiscountAmount  Price  Quantity        PLU   Id       date  \
# 29001           -0.75   6.00         1  131000010   84 2015-04-11
# 29895           -0.75   0.75         1  175000062  564 2015-04-12
# 43444           -0.11   1.50         1  221000134  365 2015-04-26
# 43798           -0.04   1.10         1  311000100  277 2015-04-26
# 57603           -0.11   1.50         1  221000134  365 2015-05-10
# 57856           -0.04   1.10         1  311000100  277 2015-05-10
# 66558           -0.04   1.10         1  311000100  277 2015-05-19
# 69966           -0.04   1.10         1  311000100  277 2015-05-23
# 70006           -0.06   1.50         1  221000134  365 2015-05-23
# 91164           -0.04   1.10         1  311000100  277 2015-06-15
#
#        SalesAmount day_of_week
# 29001         6.75    Saturday
# 29895         1.50      Sunday
# 43444         1.61      Sunday
# 43798         1.14      Sunday
# 57603         1.61      Sunday
# 57856         1.14      Sunday
# 66558         1.14     Tuesday
# 69966         1.14    Saturday
# 70006         1.56    Saturday
# 91164         1.14      Monday

# %% [markdown]
# ### Kiểm tra

# %%
# Check số lượng Discount nhỏ hơn 0
df[df['DiscountAmount'] < 0]['DiscountAmount'].count()
# Out:
# 10

# %%
# Thông tin tổng quan các Discount âm
df[df['DiscountAmount'] < 0].head()
# Out:
#                         MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 29001  8FA09DB7FC32F8750837DEA594370380  76CBDD389138090A663E9EB6F0ABDDE5
# 29895  981F33755CB678F17666ACDF270B412E  DE1246BF214A32B3313E6DAE0CE83D81
# 43444  29D0F917171EFEFEB21A3B24EA39AE05  3077EDDE25423D35500F3DF3B94CEA8A
# 43798  75846AE40A08A375822FD19395A95864  3077EDDE25423D35500F3DF3B94CEA8A
# 57603  37184C5872A9C0DF748AD2DADE740B46  57AFC6796BA512A3C2C079BBD5AFF365
#
#       CategoryDescription DepartmentDescription        Description  \
# 29001               Salad                 Salad  Rst Chicken Salad
# 29895              Add On    Add On 6in Portion     Avocado Add6in
# 43444    Bottled Beverage         Bottled Drink      Bottled Water
# 43798               Chips                 Chips              Chips
# 57603    Bottled Beverage         Bottled Drink      Bottled Water
#
#        StoreNumber  TaxInclusiveAmount  TaxAmount  AdjustedPrice  \
# 29001        12631                   0        0.0           6.75
# 29895        20974                   0        0.0           1.50
# 43444        12631                   0        0.0           1.61
# 43798        12631                   0        0.0           1.14
# 57603        12631                   0        0.0           1.61
#
#        DiscountAmount  Price  Quantity        PLU   Id       date  \
# 29001           -0.75   6.00         1  131000010   84 2015-04-11
# 29895           -0.75   0.75         1  175000062  564 2015-04-12
# 43444           -0.11   1.50         1  221000134  365 2015-04-26
# 43798           -0.04   1.10         1  311000100  277 2015-04-26
# 57603           -0.11   1.50         1  221000134  365 2015-05-10
#
#        SalesAmount day_of_week
# 29001         6.75    Saturday
# 29895         1.50      Sunday
# 43444         1.61      Sunday
# 43798         1.14      Sunday
# 57603         1.61      Sunday

# %%
# Check xem có phải cùng 1 order hay không
df[df['DiscountAmount'] < 0]['MD5KEY_ORDERSALE'].unique()
# Out:
# array(['76CBDD389138090A663E9EB6F0ABDDE5',
#        'DE1246BF214A32B3313E6DAE0CE83D81',
#        '3077EDDE25423D35500F3DF3B94CEA8A',
#        '57AFC6796BA512A3C2C079BBD5AFF365',
#        'F475A5C8875E68C5BBC59A2F4FBC17EC',
#        '4DDE9500CAE6D857B2E3F2BF1D3CBE18',
#        '8724FDCD199FBD4216089677E7789C02'], dtype=object)

# %% [markdown]
# ### Kiểm tra bảng liên quan ordersale

# %%
df_order = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/20240715/pos_ordersale_20240715.csv')

# %%
df_order.columns
# Out:
# Index(['MD5KEY_ORDERSALE', 'ChangeReceived', 'OrderNumber',
#        'TaxInclusiveAmount', 'TaxAmount', 'MealLocation', 'TransactionId',
#        'StoreNumber', 'date'],
#       dtype='object')

# %%
# Tạo df discount nhỏ hơn 0
df_discount_less_zero = df[df['DiscountAmount'] < 0]

df_merged_orders_discounts = pd.merge(df_discount_less_zero, df_order, left_on='MD5KEY_ORDERSALE', right_on='MD5KEY_ORDERSALE', how='inner')

# %%
df_merged_orders_discounts.head(10)
# Out:
#                     MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0  8FA09DB7FC32F8750837DEA594370380  76CBDD389138090A663E9EB6F0ABDDE5
# 1  981F33755CB678F17666ACDF270B412E  DE1246BF214A32B3313E6DAE0CE83D81
# 2  29D0F917171EFEFEB21A3B24EA39AE05  3077EDDE25423D35500F3DF3B94CEA8A
# 3  75846AE40A08A375822FD19395A95864  3077EDDE25423D35500F3DF3B94CEA8A
# 4  37184C5872A9C0DF748AD2DADE740B46  57AFC6796BA512A3C2C079BBD5AFF365
# 5  6C76A7741CEE1840FC52198B8DF76242  57AFC6796BA512A3C2C079BBD5AFF365
# 6  A4A0DCCB0E93E31A1BFE0246B5A11EA3  F475A5C8875E68C5BBC59A2F4FBC17EC
# 7  A0318DE9050D11A5A42016BA2328C384  4DDE9500CAE6D857B2E3F2BF1D3CBE18
# 8  AEABCC9226510356E1A5FA6C96050D12  4DDE9500CAE6D857B2E3F2BF1D3CBE18
# 9  B972812807235523EAEE771C60B2D55C  8724FDCD199FBD4216089677E7789C02
#
#   CategoryDescription DepartmentDescription        Description  StoreNumber_x  \
# 0               Salad                 Salad  Rst Chicken Salad          12631
# 1              Add On    Add On 6in Portion     Avocado Add6in          20974
# 2    Bottled Beverage         Bottled Drink      Bottled Water          12631
# 3               Chips                 Chips              Chips          12631
# 4    Bottled Beverage         Bottled Drink      Bottled Water          12631
# 5               Chips                 Chips              Chips          12631
# 6               Chips                 Chips              Chips          12631
# 7               Chips                 Chips              Chips          12631
# 8    Bottled Beverage         Bottled Drink      Bottled Water          12631
# 9               Chips                 Chips              Chips          12631
#
#    TaxInclusiveAmount_x  TaxAmount_x  AdjustedPrice  DiscountAmount  ...  \
# 0                     0          0.0           6.75           -0.75  ...
# 1                     0          0.0           1.50           -0.75  ...
# 2                     0          0.0           1.61           -0.11  ...
# 3                     0          0.0           1.14           -0.04  ...
# 4                     0          0.0           1.61           -0.11  ...
# 5                     0          0.0           1.14           -0.04  ...
# 6                     0          0.0           1.14           -0.04  ...
# 7                     0          0.0           1.14           -0.04  ...
# 8                     0          0.0           1.56           -0.06  ...
# 9                     0          0.0           1.14           -0.04  ...
#
#    SalesAmount  day_of_week  ChangeReceived  OrderNumber TaxInclusiveAmount_y  \
# 0         6.75     Saturday             0.0         4465                    0
# 1         1.50       Sunday             0.0         2113                    0
# 2         1.61       Sunday             0.0         6148                    0
# 3         1.14       Sunday             0.0         6148                    0
# 4         1.61       Sunday             0.0         7974                    0
# 5         1.14       Sunday             0.0         7974                    0
# 6         1.14      Tuesday             0.0         8974                    0
# 7         1.14     Saturday             0.0         9461                    0
# 8         1.56     Saturday             0.0         9461                    0
# 9         1.14       Monday             0.0        12089                    0
#
#    TaxAmount_y MealLocation  TransactionId  StoreNumber_y      date_y
# 0         0.60            1           4464          12631  2015-04-11
# 1         1.21            1           2113          20974  2015-04-12
# 2         0.84            1           6149          12631  2015-04-26
# 3         0.84            1           6149          12631  2015-04-26
# 4         0.55            1           7974          12631  2015-05-10
# 5         0.55            1           7974          12631  2015-05-10
# 6         0.98            1           8974          12631  2015-05-19
# 7         1.39            1           9462          12631  2015-05-23
# 8         1.39            1           9462          12631  2015-05-23
# 9         0.58            1          12090          12631  2015-06-15
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Note: Có thể xoá

# %% [markdown]
# ### Xử lý

# %%
# Loại trừ các giá trị nhỏ hơn 0
df = df[df['DiscountAmount'] >= 0]

# %%
df[df['DiscountAmount'] < 0]['DiscountAmount'].count()
# Out:
# 0

# %% [markdown]
# ## Kiểm tra outliers quantity

# %%
# Tính Q1 (25th percentile) và Q3 (75th percentile)
Q1 = df['Quantity'].quantile(0.25)
Q3 = df['Quantity'].quantile(0.75)

# Tính IQR
IQR = Q3 - Q1

# Xác định giới hạn dưới và trên
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Xác định giá trị ngoại lai
outliers = df[(df['Quantity'] < lower_bound) | (df['Quantity'] > upper_bound)]

print("Số hàng df:", df.shape[0])
print("Số hàng outliers:", outliers.shape[0])
print("% outliers:", outliers.shape[0]/df.shape[0]*100)
print("Tổng doanh thu:", df['SalesAmount'].sum())
print("Tổng doanh thu outliers:", outliers['SalesAmount'].sum())
print("% doanh thu outliers:", outliers['SalesAmount'].sum()/df['SalesAmount'].sum()*100)

print(upper_bound)
print(lower_bound)
# Out:
# Số hàng df: 91420
# Số hàng outliers: 6864
# % outliers: 7.5082038941150735
# Tổng doanh thu: 422607.57
# Tổng doanh thu outliers: 135857.33
# % doanh thu outliers: 32.14739622387739
# 1.0
# 1.0

# %%
df['Quantity'].describe()
# Out:
# count    91420.000000
# mean         1.092113
# std          0.534968
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         75.000000
# Name: Quantity, dtype: float64

# %% [markdown]
# #### Kiểm tra chi tiết phân bố dữ liệu của Quantity
# Kiểm tra xem có bao nhiêu giá trị quantity duy nhất và phân bố của các giá trị để biết được số lượng sản phẩm trong 1 đơn hàng

# %%
df['Quantity'].value_counts()
# Out:
# Quantity
# 1     84556
# 2      6136
# 3       425
# 4       204
# 6        31
# 5        28
# 8        15
# 12        5
# 10        5
# 7         5
# 30        2
# 24        1
# 45        1
# 75        1
# 18        1
# 14        1
# 15        1
# 20        1
# 60        1
# Name: count, dtype: int64

# %%
# Tính tổng số lượng
total_quantity = df['Quantity'].count()

# Thêm cột phần trăm
result_df = df.groupby('Quantity').agg(
    total=('Quantity', 'count')
).assign(
    percent=lambda x: (x['total'] / total_quantity) * 100
)

result_df
# Out:
#           total    percent
# Quantity
# 1         84556  92.491796
# 2          6136   6.711879
# 3           425   0.464887
# 4           204   0.223146
# 5            28   0.030628
# 6            31   0.033909
# 7             5   0.005469
# 8            15   0.016408
# 10            5   0.005469
# 12            5   0.005469
# 14            1   0.001094
# 15            1   0.001094
# 18            1   0.001094
# 20            1   0.001094
# 24            1   0.001094
# 30            2   0.002188
# 45            1   0.001094
# 60            1   0.001094
# 75            1   0.001094

# %%
print(df['Quantity'].quantile(0.92))
print(df['Quantity'].quantile(0.93))

# %%
plt.figure(figsize=(20, 7))

ax = sns.barplot(data= df, x='date', y='Quantity')
    
plt.xticks(rotation=90, ha='center')

plt.show()

# %%
num_stores = df['StoreNumber'].unique()

plt.figure(figsize=(20, 7 * len(num_stores)))  # Sửa lỗi ở đây

for index, store in enumerate(df['StoreNumber'].unique(), start=1):
    plt.subplot(len(num_stores), 2, index)
    ax = sns.barplot(data=df[df['StoreNumber'] == store], x='date', y='Quantity')
    plt.xticks(rotation=90, ha='center')
    plt.title(f'Store {store}')

plt.tight_layout()
plt.show()

# %%
# Kiểm tra các đơn hàng có số lượng sản phẩm cao
df_quantity = outliers[outliers['Quantity']>= 40]

# %%
df_quantity.columns
# Out:
# Index(['MD5KEY_MENUITEM', 'MD5KEY_ORDERSALE', 'CategoryDescription',
#        'DepartmentDescription', 'Description', 'StoreNumber',
#        'TaxInclusiveAmount', 'TaxAmount', 'AdjustedPrice', 'DiscountAmount',
#        'Price', 'Quantity', 'PLU', 'Id', 'date', 'SalesAmount', 'day_of_week'],
#       dtype='object')

# %%
df_merged_quantity_order = pd.merge(df_quantity, df_order, on='MD5KEY_ORDERSALE', how="inner")

# %%
df_merged_quantity_order
# Out:
#                     MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0  7AFF6F9A39CC2CBBD33DFFFDF213DA88  B6BA5DC2E5670B796E57C435A64E8E60
# 1  120875AC5766ED916C913794EA77BC50  68CBE43FC25B5EE67846D4489638732C
# 2  CED03E3D17732D7A30CF169E574AC9F9  68CBE43FC25B5EE67846D4489638732C
#
#   CategoryDescription DepartmentDescription              Description  \
# 0            Footlong          Footlong Sub            Turkey FtLong
# 1            Footlong          Footlong Sub  Big Hot Pastrami FtLong
# 2               Chips                 Chips                    Chips
#
#    StoreNumber_x  TaxInclusiveAmount_x  TaxAmount_x  AdjustedPrice  \
# 0           4904                     0      43.0312         506.25
# 1           4904                     0      29.0700         342.00
# 2           4904                     0       5.6100          66.00
#
#    DiscountAmount  ...  SalesAmount  day_of_week  ChangeReceived  OrderNumber  \
# 0            0.00  ...     37968.75     Saturday             0.0        11491
# 1           29.25  ...     15390.00     Saturday             0.0        12484
# 2            6.00  ...      3960.00     Saturday             0.0        12484
#
#   TaxInclusiveAmount_y  TaxAmount_y MealLocation  TransactionId  \
# 0                    0        43.23            0          11491
# 1                    0        37.40            0          12495
# 2                    0        37.40            0          12495
#
#    StoreNumber_y      date_y
# 0           4904  2015-05-16
# 1           4904  2015-05-23
# 2           4904  2015-05-23
#
# [3 rows x 25 columns]

# %% [markdown]
# ### Note: Khi phân tích báo cáo liên quan tới Quantity tách các giá trị ngoại lai để phân tích
# Chú ý cửa hàng 4904

# %% [markdown]
# ## Kiểm tra outliers price

# %%
# Tính Q1 (25th percentile) và Q3 (75th percentile)
Q1_Price = df['Price'].quantile(0.25)
Q3_Price = df['Price'].quantile(0.75)

# Tính IQR
IQR_Price = Q3_Price - Q1_Price

# Xác định giới hạn dưới và trên
lower_bound_Price = Q1_Price - 1.5 * IQR_Price
upper_bound_Price = Q3_Price + 1.5 * IQR_Price

# Xác định giá trị ngoại lai
outliers_Price = df[(df['Price'] < lower_bound_Price) | (df['Price'] > upper_bound_Price)]

print("Số hàng df:", df.shape[0])
print("Số hàng outliers:", outliers_Price.shape[0])
print("% outliers:", outliers_Price.shape[0]/df.shape[0]*100)
print("Tổng doanh thu:", df['SalesAmount'].sum())
print("Tổng doanh thu outliers:", outliers_Price['SalesAmount'].sum())
print("% doanh thu outliers:", outliers_Price['SalesAmount'].sum()/df['SalesAmount'].sum()*100)
# Out:
# Số hàng df: 91420
# Số hàng outliers: 46
# % outliers: 0.05031721723911616
# Tổng doanh thu: 422607.57
# Tổng doanh thu outliers: 2834.0
# % doanh thu outliers: 0.6705984940118322

# %%
outliers_Price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 1343 to 91382
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MD5KEY_MENUITEM        46 non-null     object
#  1   MD5KEY_ORDERSALE       46 non-null     object
#  2   CategoryDescription    46 non-null     object
#  3   DepartmentDescription  46 non-null     object
#  4   Description            46 non-null     object
#  5   StoreNumber            46 non-null     int64
#  6   TaxInclusiveAmount     46 non-null     int64
#  7   TaxAmount              46 non-null     float64
#  8   AdjustedPrice          46 non-null     float64
#  9   DiscountAmount         46 non-null     float64
#  10  Price                  46 non-null     float64
#  11  Quantity               46 non-null     int64
#  12  PLU                    46 non-null     int64
#  13  Id                     46 non-null     int64
#  14  date                   46 non-null     datetime64[ns]
#  15  SalesAmount            46 non-null     float64
#  16  day_of_week            46 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(5), object(6)
# memory usage: 6.5+ KB

# %%
outliers_Price[['CategoryDescription', 'DepartmentDescription', 'Description', 'StoreNumber']].head()
# Out:
#       CategoryDescription DepartmentDescription  \
# 1343            Cash Card             Cash Card
# 3095            Cash Card             Cash Card
# 7410             Catering      Sandwich Platter
# 7826             Catering      Sandwich Platter
# 20266           Cash Card             Cash Card
#
#                           Description  StoreNumber
# 1343    Subway Cash Card Activate $25        46673
# 3095   Subway Cash Card Activate Any$        12631
# 7410             Classic Combo SndPlt        46673
# 7826             Flavor Craver SndPlt        46673
# 20266  Subway Cash Card Activate Any$        20974

# %% [markdown]
# ### Note: Check sản phẩm thẻ mua hàng

# %%
print(outliers_Price['StoreNumber'].value_counts())
outliers_Price.groupby(['CategoryDescription',
                        'DepartmentDescription',
                        'Description',
                        'StoreNumber']).agg(TotalQuantity=('Quantity', 'sum')).reset_index()
# Out:
# StoreNumber
# 4904     28
# 46673     7
# 20974     6
# 12631     5
# Name: count, dtype: int64
#    CategoryDescription DepartmentDescription                     Description  \
# 0            Cash Card             Cash Card   Subway Cash Card Activate $20
# 1            Cash Card             Cash Card   Subway Cash Card Activate $25
# 2            Cash Card             Cash Card   Subway Cash Card Activate $25
# 3            Cash Card             Cash Card   Subway Cash Card Activate $25
# 4            Cash Card             Cash Card   Subway Cash Card Activate $50
# 5            Cash Card             Cash Card  Subway Cash Card Activate Any$
# 6            Cash Card             Cash Card  Subway Cash Card Activate Any$
# 7            Cash Card             Cash Card  Subway Cash Card Activate Any$
# 8             Catering      Sandwich Platter            Classic Combo SndPlt
# 9             Catering      Sandwich Platter            Classic Combo SndPlt
# 10            Catering      Sandwich Platter            Flavor Craver SndPlt
# 11            Catering      Sandwich Platter            Standard Base SndPlt
# 12            Catering      Sandwich Platter         Subway Fresh Fit SndPlt
#
#     StoreNumber  TotalQuantity
# 0          4904              2
# 1          4904             24
# 2         20974              1
# 3         46673              1
# 4         20974              1
# 5          4904              2
# 6         12631              3
# 7         20974              4
# 8         12631              1
# 9         46673              5
# 10        46673              2
# 11        12631              1
# 12        46673              8

# %%
plt.figure(figsize=(16, 8))

sns.barplot(data=outliers_Price.groupby(['CategoryDescription',
                        'DepartmentDescription',
                        'Description',
                        'StoreNumber']).agg(
                          TotalQuantity=('Quantity', 'sum')
                        ).reset_index(),
            x='Description',
            y='TotalQuantity',
            hue='StoreNumber')

plt.xticks(rotation=45, ha='center')
plt.show()

# %%
df_store = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/processed/20240715/store_restaurant_20240715.csv')

# %%
df_store.head()
# Out:
#    STORE_ADDRESS1 STORE_ADDRESS2 DISTRIBUTION_REGION STORE_STATE STORE_CITY  \
# 0    Ninth Street            NaN             Western  California   Berkeley
# 1     Shattuck Sq        Shop #6             Western  California   Berkeley
# 2   Myrtle Avenue            NaN           Northeast    New York  Ridgewood
# 3  Whitney Avenue            NaN           Northeast    New York   Elmhurst
#
#    STORE_ZIP   STORE_TYPE STORE_LOYALTY_FLAG  STORE_NUMBER
# 0      94710  Traditional                  N         46673
# 1      94704  Traditional                  Y          4904
# 2      11385  Traditional                  Y         12631
# 3      11373  Traditional                  Y         20974

# %%
outliers_Price_store = pd.merge(outliers_Price, df_store, left_on='StoreNumber', right_on='STORE_NUMBER', how='inner')

# %%
outliers_Price_store.head(5)
# Out:
#                     MD5KEY_MENUITEM                  MD5KEY_ORDERSALE  \
# 0  C5A2A5F1A9939E30FF084713BAA7381C  9C397080F72347426FAC6EB297B077A1
# 1  E7DC1E576FA69068196CA9F5687D16C2  8E51ED8B3C48212BC8AB0EA3CE7C4F7B
# 2  1EDEEDAD8FEA8845095D2AE5E1BCD50C  35CC89B730B548B99CF4EC25F80E19AB
# 3  A8533BAFD348666C01B23AB11A8FA8D1  35CC89B730B548B99CF4EC25F80E19AB
# 4  2F820394E5273CC76FF8A47016F76A46  889D0905DC89FF7E6E36990C6E0B41ED
#
#   CategoryDescription DepartmentDescription                     Description  \
# 0           Cash Card             Cash Card   Subway Cash Card Activate $25
# 1           Cash Card             Cash Card  Subway Cash Card Activate Any$
# 2            Catering      Sandwich Platter            Classic Combo SndPlt
# 3            Catering      Sandwich Platter            Flavor Craver SndPlt
# 4           Cash Card             Cash Card  Subway Cash Card Activate Any$
#
#    StoreNumber  TaxInclusiveAmount  TaxAmount  AdjustedPrice  DiscountAmount  \
# 0        46673                   0        0.0           25.0             0.0
# 1        12631                   0        0.0           30.0             0.0
# 2        46673                   0        0.0           38.0             0.0
# 3        46673                   0        0.0           76.0             0.0
# 4        20974                   0        0.0           15.0             0.0
#
#    ...  day_of_week  STORE_ADDRESS1  STORE_ADDRESS2  DISTRIBUTION_REGION  \
# 0  ...       Sunday    Ninth Street             NaN              Western
# 1  ...     Thursday   Myrtle Avenue             NaN            Northeast
# 2  ...     Thursday    Ninth Street             NaN              Western
# 3  ...     Thursday    Ninth Street             NaN              Western
# 4  ...     Thursday  Whitney Avenue             NaN            Northeast
#
#   STORE_STATE  STORE_CITY STORE_ZIP   STORE_TYPE STORE_LOYALTY_FLAG  \
# 0  California    Berkeley     94710  Traditional                  N
# 1    New York   Ridgewood     11385  Traditional                  Y
# 2  California    Berkeley     94710  Traditional                  N
# 3  California    Berkeley     94710  Traditional                  N
# 4    New York    Elmhurst     11373  Traditional                  Y
#
#   STORE_NUMBER
# 0        46673
# 1        12631
# 2        46673
# 3        46673
# 4        20974
#
# [5 rows x 26 columns]

# %%
storeId = outliers_Price['StoreNumber'].value_counts()
outliers_Price_store.groupby(['StoreNumber',
                              'DISTRIBUTION_REGION',
                              'STORE_STATE',
                              'STORE_CITY']).agg(
                                TotalQuantity=('Quantity', 'sum'),
                                TotalSale=('SalesAmount', 'sum'))
# Out:
#                                                         TotalQuantity  \
# StoreNumber DISTRIBUTION_REGION STORE_STATE STORE_CITY
# 4904        Western             California  Berkeley               28
# 12631       Northeast           New York    Ridgewood               5
# 20974       Northeast           New York    Elmhurst                6
# 46673       Western             California  Berkeley               16
#
#                                                         TotalSale
# StoreNumber DISTRIBUTION_REGION STORE_STATE STORE_CITY
# 4904        Western             California  Berkeley        715.0
# 12631       Northeast           New York    Ridgewood       158.0
# 20974       Northeast           New York    Elmhurst        150.0
# 46673       Western             California  Berkeley       1811.0

# %% [markdown]
# #### Note: Đa số các món có giá outlier nằm ở cửa hàng 4904, nhưng giá trị mang về của 46673 là cao nhất

# %%
plt.figure(figsize=(16, 8))

sns.barplot(data=outliers_Price_store.groupby(['StoreNumber',
                              'DISTRIBUTION_REGION',
                              'STORE_STATE',
                              'STORE_CITY']).agg(
                                TotalQuantity=('Quantity', 'sum'),
                                TotalSale=('SalesAmount', 'sum')),
            x='StoreNumber',
            y='TotalQuantity',
            hue='TotalSale')

plt.xticks(rotation=45, ha='center')
plt.show()

# %% [markdown]
# ## Check xem cash card trong đơn hàng
