# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import sys
import os
sys.path.append('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/scripts/')
import data_cleaning

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('/Users/sonnguyen/Dropbox/My Mac (Son’s MacBook Air)/Documents/1. Data Analytics/CoderSchool/FinalProject/data/raw/menu_items.csv')

# %%
df.head()
# Out:
#                    MenuItemName                         MenuItemDescription  \
# 0  FtL/Ham                       Ham FtLong
# 1  Six/Ham                       Ham 6 inch
# 2  FfB/Ham                       Ham FtFbd
# 3  fBd/Ham                       Ham FlatBd
# 4  Sld/Ham                       Ham Salad
#
#          PLU  MenuItemId  RecipeId
# 0  111000004           1         6
# 1  121000004           2         7
# 2  112000004           3         2
# 3  122000004           4         8
# 4  131000004           5         9

# %% [markdown]
# # 1. Kiểm tra kiểu dữ liệu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8005 entries, 0 to 8004
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MenuItemName         8005 non-null   object
#  1   MenuItemDescription  8005 non-null   object
#  2   PLU                  8005 non-null   int64
#  3   MenuItemId           8005 non-null   int64
#  4   RecipeId             8005 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 312.8+ KB

# %%
df.shape
# Out:
# (8005, 5)

# %% [markdown]
# # 2. Kiểm tra xử lý khoảng trắng

# %% [markdown]
# ## 2.1 Kiểm tra

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['MenuItemName', 'MenuItemDescription'], dtype='object')

# %%
df['MenuItemName'].unique()
# Out:
# array(['FtL/Ham                     ', 'Six/Ham                     ',
#        'FfB/Ham                     ', ...,
#        'dm6/BCBPin                  ', 'Wrp/ChkSldPreM              ',
#        'Wrp/OrChSl                  '], dtype=object)

# %% [markdown]
# ## 2.2 Xử lý

# %%
df = data_cleaning.remove_whitespace(df)

# %%
df['MenuItemName'].unique()
# Out:
# array(['FtL/Ham', 'Six/Ham', 'FfB/Ham', ..., 'dm6/BCBPin',
#        'Wrp/ChkSldPreM', 'Wrp/OrChSl'], dtype=object)

# %%
df[df['MenuItemName'] == "..."]
# Out:
# Empty DataFrame
# Columns: [MenuItemName, MenuItemDescription, PLU, MenuItemId, RecipeId]
# Index: []

# %% [markdown]
# # 3. Kiểm tra giá trị thiếu

# %%
df.isna().sum()
# Out:
# MenuItemName           0
# MenuItemDescription    0
# PLU                    0
# MenuItemId             0
# RecipeId               0
# dtype: int64

# %% [markdown]
# # 4. Kiểm tra trùng lặp

# %%
df.duplicated().sum()
# Out:
# 0
